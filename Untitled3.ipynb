# %%
# !CUDA_VISIBLE_DEVICES=0 python test.py --model 'trans_unet' --ckpt_path_A2C './transunet_model_out/test19/epoch_299.pth' --ckpt_path_A4C './transunet_model_out/test19/epoch_299.pth' --img_size 512 --batch_size 2
# Out:
# /opt/conda/lib/python3.6/site-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,
# => merge config from configs/swin_tiny_patch4_window7_224_lite.yaml
# (16, 16) (32, 32)
# ...

# %%
(0.94294509 + 0.9655531) / 2, (0.89542161 + 0.93391342) / 2
# Out:
# (0.954249095, 0.914667515)

# %%
(0.94598527 + 0.9661155) / 2, (0.89985168 + 0.93483479) / 2
# Out:
# (0.956050385, 0.917343235)

# %%
# !CUDA_VISIBLE_DEVICES=0 python test.py --model 'trans_unet' --ckpt_path_A2C './transunet_model_out/test15/epoch_249.pth' --ckpt_path_A4C './transunet_model_out/test15/epoch_249.pth' --img_size 512 --batch_size 2
# Out:
# /opt/conda/lib/python3.6/site-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,
# => merge config from configs/swin_tiny_patch4_window7_224_lite.yaml
# (16, 16) (32, 32)
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python test.py --model 'trans_unet' --ckpt_path_A2C './transunet_model_out/test15/epoch_249.pth' --ckpt_path_A4C './transunet_model_out/test15/epoch_249.pth' --img_size 512 --batch_size 2
# Out:
# /opt/conda/lib/python3.6/site-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,
# => merge config from configs/swin_tiny_patch4_window7_224_lite.yaml
# (16, 16) (32, 32)
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python test.py --model 'trans_unet' --ckpt_path_A2C './transunet_model_out/test15/epoch_249.pth' --ckpt_path_A4C './transunet_model_out/test15/epoch_249.pth' --img_size 512 --batch_size 2
# Out:
# /opt/conda/lib/python3.6/site-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,
# => merge config from configs/swin_tiny_patch4_window7_224_lite.yaml
# (16, 16) (32, 32)
# ...

# %%
# !CUDA_VISIBLE_DEVICES=1 python test.py --model 'trans_unet' --ckpt_path_A2C './transunet_model_out/test22/epoch_299.pth' --ckpt_path_A4C './transunet_model_out/test22/epoch_299.pth' --img_size 384 --batch_size 2
# Out:
# /opt/conda/lib/python3.6/site-packages/albumentations/augmentations/transforms.py:691: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,
# => merge config from configs/swin_tiny_patch4_window7_224_lite.yaml
# (16, 16) (24, 24)
# ...
